# %% [markdown]
# Homework 2
# Problem 1
# Chris Nolan

# %% [markdown]
# The only data cleaning that was done in this data set was a missing value in assault and it was replaced with the average for the column.

# %% [markdown]
# Graph of Murder rate by state.
#
# ![image.png](attachment:59255949-8de0-42fa-ac35-38625cf0fa6e.png)

# %% [markdown]
# Graph of assaults by state
#
# ![image.png](attachment:3d50e137-c2f1-4bdf-a539-2e1b23e75f58.png)

# %% [markdown]
# Murder rate Vs. Assault rate by state
#
# ![image.png](attachment:9da8cee7-aed2-458a-9592-dcc6d0342c38.png)

# %% [markdown]
# Replace all null values from assault with the average using SQL
#
# Update USArrests
# Set Assault = (select avg(Assault) from USArrests)
# Where Assault is null;
#
# As a result of this command Georgia assault rate was replaced with 169.93

# %% [markdown]
# Find the Min from all numeric data
#
# ![image.png](attachment:9011b47d-2daf-45b0-bf97-15f25d671ba3.png)

# %% [markdown]
# Find the max from all the numeric data.
#
# ![image.png](attachment:6e161a56-a40f-42cd-9d00-d6ecaf3df2c4.png)

# %% [markdown]
# Find the mean from all numeric data
#
# ![image.png](attachment:ad1cab3a-fce9-4d54-b768-ae5d7c774e64.png)

# %% [markdown]
# Find the variance from all numeric data
#
# ![image.png](attachment:215fd5ec-6e56-495a-a28f-0416046a80d8.png)

# %% [markdown]
# Which state has the maximum murder rate?
# ![image.png](attachment:1d09a51b-90e2-48b7-b314-95b60f6f0964.png)
# List of states in ascending order of urban population percentages.
# ![image.png](attachment:1bd0977e-a5a6-48fd-ab8c-4c6556e6ac88.png)
# How many states have higher murder rates than Arizona? List those states.
# ![image.png](attachment:32536e58-dfa6-40a1-a222-dadba777a65a.png)
# Total count is 21
# |State|Murder|
# | --- | --- |
# |Virginia|8.5|
# |Arkansas|8.8|
# |California|9|
# |Missouri|9|
# |Kentucky|9.7|
# |Alaska|10|
# |Illinois|10.4|
# |New York|11.1|
# |Maryland|11.3|
# |New Mexico|11.4|
# |Michigan|12.1|
# |Nevada|12.2|
# |Texas|12.7|
# |North Carolina|13|
# |Alabama|13.2|
# |Tennessee|13.2|
# |South Carolina|14.4|
# |Florida|15.4|
# |Louisiana|15.4|
# |Mississippi|16.1|
# |Georgia|17.4|

# %% [markdown]
# Problem 2

# %% [markdown]
# First I had to add the commas to the text file in order to make it a cvs format.

# %% [markdown]
# After that I replaced all values with the average from their respective columns.

# %% [markdown]
# Under-ﬁve mortality rate and neonatal mortality rate.
# ![image.png](attachment:2d482090-d946-444b-839b-8325037a2ca1.png)
# Infant mortality rate and neonatal mortality rate.
# ![image.png](attachment:9af20d1a-3833-49d0-994c-9d196a66a16c.png)
# Year and infant mortality rate.
# ![image.png](attachment:95d2be0f-1451-4580-9af2-cf2af1fc31f9.png)

# %% [markdown]
# Insert the csv file in SQL
# ![image.png](attachment:db6dc6de-5fd7-44db-ba5d-364664d35fc9.png)

# %% [markdown]
# Use SQL to fill in the missing values in each column using the medians.
# ![image.png](attachment:fbf71392-9316-4864-9be0-48bf1af1b9f3.png)

# %% [markdown]
# -- Display the entire table.
# ![image.png](attachment:54bc7c17-65d5-4892-b46c-3ceba2bbc0f0.png)
# -- Which years have the lowest and highest infant mortality years, respectively?
# ![image.png](attachment:f5debcf4-3498-4ba8-ac60-749370334f1a.png)
# -- In what years the neonatal mortality rates were above average?
# ![image.png](attachment:163d5419-7c7c-4713-ae55-b13628c83f8c.png)
# -- Display the sorted infant mortality rates in descending order.
# ![image.png](attachment:ac32dc92-60be-41b7-ab97-b4fcba17da7d.png)
# -- Display min, max, mean, variance, and standard deviation for each mortality rate.
# Under five mortality
# ![image.png](attachment:c629d234-598c-481b-ad48-8ba898a9419e.png)
# Infant mortality rate
# ![image.png](attachment:ea823752-1908-4aff-a6c1-bf4b48359d85.png)
# Neonatal mortality rate
# ![image.png](attachment:befa40cb-d72f-4165-9abf-1a8377b6bddc.png)
# -- Add a new column called Above-Five Mortality Rate and populate it with appropriate values.
# ![image.png](attachment:8d0c22f0-58d4-4bc0-92cf-0f09179b8204.png)
# I choose to update the table with all zeros since we have no other data of this type to help infer what value should be placed there
# ![image.png](attachment:47679fc0-97b1-4351-9cc9-cdceaa9c2253.png)
# -- Display the entire table again.
# ![image.png](attachment:8d3f36c1-2f73-4845-8e3c-63b63a95e8bd.png)
