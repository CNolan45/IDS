# %% [markdown]
# Problem 1:
#
# Total Statistics
# Mean = 243.7786
# Min = 179
# Max = 332
#
# Horsebean Statistics
# Mean = 158.3035
# Min = 140
# Max = 179
#
# Linseed Statistics
# Mean = 289.3769
# Min = 271
# Max = 309
#
# Soybean Statistics
# Mean = 245.4973
# Min = 243
# Max = 248
#
# Sunflower Statistics
# Mean = 366.7615
# Min = 318
# Max = 423
#
# Meatmeal Statistics
# Mean = 289.5686
# Min = 258
# Max = 325
#
# Casein Statistics
# Mean = 349.5368
# Min = 332
# Max = 368
#
# ![image.png](attachment:b83f5b43-61ae-4142-b7fc-e920ff413331.png)
#
# After looking at all the data I belive that the best chicken feed to use is the Sunflower seeds since they produce the highest weight on average in the chickens. Also since the sunflower seeds have the biggest chicken which means there it also has the highest theoretical max size.

# %% [markdown]
# Problem 2:
#
# Geico
# Mean = 7.106481
# Min = 4.7
# Max = 9.2
#
# Progressive
# Mean = 7.61317
# Min = 6.7
# Max = 8.9
#
# USAA
# Mean = 5.788105
# Min = 3.8
# Max = 8.1
#
# If I was to choose an insurance provider based on the data provided I would choose Progressive. I would choose this company since it has the highest mean and the lowest score is the lowest of the 3 companies listed. While it does not have the absoulte highest score on average the customers are happier than the other companies.
